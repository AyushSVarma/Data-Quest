# %%
import pandas as pd
import boto3
from io import StringIO
#3.1/3.2
import os

# os.environ['AWS_ACCESS_KEY_ID'] = 'ASIAUAF7MHJCBULZP24D'
# os.environ['AWS_SECRET_ACCESS_KEY'] = '2CqM/VqlAXG9QnbzL+p2AMNbtXlXFg4VpgdkP7YN'
# os.environ['AWS_SESSION_TOKEN'] = '...'
df_json = pd.read_json("s3://ayush-data-quest-tf/api_output.json")
df_csv = pd.read_csv("s3://ayush-data-quest-tf/pr.data.0.Current", sep ='\t')

df_json.columns = df_json.columns.str.lower()
df_csv.columns = df_csv.columns.str.strip()
print(df_json.iloc[[3,4,5,6,7,8]]["population"].mean())
print(df_json.iloc[[3,4,5,6,7,8]]["population"].std())

yearly_sums = df_csv.groupby(['series_id', 'year'])['value'].sum().reset_index()

indices = (yearly_sums.groupby('series_id')['value']).idxmax()
best_years = yearly_sums.loc[indices].reset_index()
best_years_sorted = best_years.sort_values(by='value', ascending=False)
print(best_years_sorted)

df = pd.merge(df_json, df_csv, on='year')
df['series_id'] = df['series_id'].str.strip()
df['period'] = df['period'].str.strip()
# print(df)
filtered_df = df[(df['series_id'] == 'PRS30006032') & (df['period'] == 'Q01')]
print(filtered_df[['series_id', 'year', 'population','period', 'value']])
# Out:
# 317437383.0
# 4257089.5415293295
#      index          series_id  year    value
# 275   7912  PRS88003183        2022  877.438
# 278   7999  PRS88003193        2022  765.817
# 92    2608  PRS32006013        1995  725.222
# 155   4433  PRS84006083        2023  718.857
# 200   5738  PRS85006083        2023  717.262
# ..     ...                ...   ...      ...
# 139   3956  PRS84006022        2010    7.500
# 184   5261  PRS85006022        2010    7.500
# 228   6537  PRS88003021        2010    6.400
# 183   5232  PRS85006021        2010    6.000
# 138   3927  PRS84006021        2010    5.900
#
# [282 rows x 4 columns]
#         series_id  year  population period  value
# 35    PRS30006032  2021   329725481    Q01    1.3
# 1265  PRS30006032  2020   326569308    Q01   -6.5
# 2495  PRS30006032  2019   324697795    Q01   -2.4
# 3725  PRS30006032  2018   322903030    Q01   -0.1
# 4955  PRS30006032  2017   321004407    Q01    1.0
# 6185  PRS30006032  2016   318558162    Q01   -1.8
# ...

# %%
pip install s3fs
# Out:
# ...
#                                               0.0/76.1 kB ? eta -:--:--
#      ---------------------------------------- 76.1/76.1 kB 2.1 MB/s eta 0:00:00
# ...
#                                               0.0/170.9 kB ? eta -:--:--
#      ------------------------------------   163.8/170.9 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------- 170.9/170.9 kB 3.5 MB/s eta 0:00:00
# ...
#                                               0.0/365.2 kB ? eta -:--:--
#      ----------                               92.2/365.2 kB ? eta -:--:--
#      -------------------------------------- 365.2/365.2 kB 4.6 MB/s eta 0:00:00
# ...
#                                               0.0/11.9 MB ? eta -:--:--
#      -                                        0.3/11.9 MB 7.0 MB/s eta 0:00:02
#      --                                       0.7/11.9 MB 8.4 MB/s eta 0:00:02
#      ---                                      1.0/11.9 MB 8.1 MB/s eta 0:00:02
# ...
